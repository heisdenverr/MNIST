# %% [markdown]
# <a href="https://colab.research.google.com/github/heisdenverr/MNIST/blob/master-branch/predictive_maintenance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import data

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shivamb/machine-predictive-maintenance-classification")

print("Path to dataset files:", path)

# %%
import os
import pandas as pd

df_csv = os.path.join(path, "predictive_maintenance.csv")
df = pd.read_csv(df_csv)
df

# %%
df.tail()
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 9995                    1604         29.5               14       0
# 9996                    1632         31.8               17       0
# 9997                    1645         33.4               22       0
# 9998                    1408         48.5               25       0
# 9999                    1500         40.2               30       0
#
#      Failure Type
# 9995   No Failure
# 9996   No Failure
# 9997   No Failure
# 9998   No Failure
# 9999   No Failure

# %%
df.shape
# Out:
# (10000, 10)

# %%
target_c = (df['Target']==0).sum()
target_c
# Out:
# np.int64(9661)

# %%
print(10000 - 9661)
# Out:
# 339

# %%
failure_type = df['Failure Type']
failure_type
# Out:
# 0       No Failure
# 1       No Failure
# 2       No Failure
# 3       No Failure
# 4       No Failure
#            ...
# 9995    No Failure
# 9996    No Failure
# 9997    No Failure
# 9998    No Failure
# 9999    No Failure
# Name: Failure Type, Length: 10000, dtype: object

# %%
false_target = df[df['Target'] == 0]
false_target
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# ...

# %%
true_target = df[df['Target'] > 0]
true_target
# Out:
#        UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 50      51     L47230    L                298.9                    309.1
# 69      70     L47249    L                298.9                    309.0
# 77      78     L47257    L                298.8                    308.9
# 160    161     L47340    L                298.4                    308.2
# 161    162     L47341    L                298.3                    308.1
# ...    ...        ...  ...                  ...                      ...
# 9758  9759     L56938    L                298.6                    309.8
# 9764  9765     L56944    L                298.5                    309.5
# 9822  9823     L57002    L                298.5                    309.4
# 9830  9831     L57010    L                298.3                    309.3
# 9974  9975     L57154    L                298.6                    308.2
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# ...

# %% [markdown]
# data type
# Multi-label classification

# %%
df = df.drop('Failure Type', axis=1)
df
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target
# ...

# %%
x = df.drop('UDI', axis=1)
y = df['Target']
x
# Out:
#      Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0        M14860    M                298.1                    308.6
# 1        L47181    L                298.2                    308.7
# 2        L47182    L                298.1                    308.5
# 3        L47183    L                298.2                    308.6
# 4        L47184    L                298.2                    308.7
# ...         ...  ...                  ...                      ...
# 9995     M24855    M                298.8                    308.4
# 9996     H39410    H                298.9                    308.4
# 9997     M24857    M                299.0                    308.6
# 9998     H39412    H                299.0                    308.7
# 9999     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target
# 0                       1551         42.8                0       0
# ...

# %%
from matplotlib import pyplot as plt
x.plot(kind='scatter', x='Rotational speed [rpm]', y='Torque [Nm]', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
x.plot(kind='scatter', x='Air temperature [K]', y='Process temperature [K]', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
x['Process temperature [K]'].plot(kind='line', figsize=(8, 4), title='Process temperature [K]')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
x['Air temperature [K]'].plot(kind='line', figsize=(8, 4), title='Air temperature [K]')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
x = pd.get_dummies(x, columns=['Product ID', 	'Type'], drop_first=True,dtype=int)
x
# Out:
#       Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0                   298.1                    308.6                    1551
# 1                   298.2                    308.7                    1408
# 2                   298.1                    308.5                    1498
# 3                   298.2                    308.6                    1433
# 4                   298.2                    308.7                    1408
# ...                   ...                      ...                     ...
# 9995                298.8                    308.4                    1604
# 9996                298.9                    308.4                    1632
# 9997                299.0                    308.6                    1645
# 9998                299.0                    308.7                    1408
# 9999                299.0                    308.7                    1500
#
#       Torque [Nm]  Tool wear [min]  Target  Product ID_H29425  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8000, 10007), (2000, 10007), (8000,), (2000,))

# %%
rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    class_weight='balanced',
    random_state=42

  )

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
y_pred = rf.predict(X_test)
y_proba = rf.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred))

print(confusion_matrix(y_test, y_pred))

print('ROC-AUX:', roc_auc_score(y_test, y_proba))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1932
#            1       1.00      1.00      1.00        68
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000
#
# [[1932    0]
#  [   0   68]]
# ROC-AUX: 0.9999999999999999

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(rf, x, y, cv=5, scoring='f1')
print("CV F1-scores:", scores)
print("Mean CV F1:", scores.mean())
# Out:
# CV F1-scores: [1.         1.         1.         0.99259259 1.        ]
# Mean CV F1: 0.9985185185185184
